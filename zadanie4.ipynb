# %% [markdown]
# <a href="https://colab.research.google.com/github/Maro94/wstep-do-ml-mariuszmallek19389B1-175ic/blob/main/zadanie4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup  
from openpyxl import Workbook
from google.colab import files
wb = files.upload()
from openpyxl import Workbook
wb = Workbook()

ws=wb.active 
#utworzenie arkuszow
gielda = wb.create_sheet("Giełda")
linki = wb.create_sheet("Linki")
filmweb = wb.create_sheet("Filmweb")
wb = Workbook()
wb.save('wb.xlsx')
# Out:
#      <input type="file" id="files-fdeb9439-4e7b-43a2-b24b-330d4c707d16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdeb9439-4e7b-43a2-b24b-330d4c707d16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wb.xlsx to wb.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import re

odpowiedz = requests.get("https://www.filmweb.pl/film/To%3A+Rozdział+2-2019-793838")
html_doc = odpowiedz.text
soup = BeautifulSoup(odpowiedz.text, 'html.parser')
rezyseria = soup.find(text="reżyseria").next_element.find("a").text.strip()
premiera = soup.find(text="premiera").next_element.find("a").text.strip()
ocena = soup.find("span", itemprop="ratingValue").text.strip()
boxoffice = soup.find(text="boxoffice").next_element.text
print(f"ocena: {ocena}, rezyseria:{rezyseria}, premiera: {premiera}, boxoffice:{boxoffice}")
# Out:
# ocena: 6,1, rezyseria:Andy Muschietti, premiera: 26 sierpnia 2019 (świat), boxoffice:$473 093 228 na świecie$211 593 228 w USA$261 500 000 poza USA

# %%
import requests
from bs4 import BeautifulSoup

odpowiedz = requests.get("http://trojmiasto.pl")
soup = BeautifulSoup(odpowiedz.text, 'html.parser')

for link in soup.find_all('a', href=True):
    print(f"{link.get('href')} ")
# Out:
# https://www.trojmiasto.pl/
# https://katalog.trojmiasto.pl/gastronomia_i_jedzenie/jedzenie_na_telefon/
# https://mapa.trojmiasto.pl/
# https://ogloszenia.trojmiasto.pl/
# https://ogloszenia.trojmiasto.pl/nauka-jezyka/
# https://ogloszenia.trojmiasto.pl/nieruchomosci/
# https://ogloszenia.trojmiasto.pl/nieruchomosci-rynek-wtorny/
# https://ogloszenia.trojmiasto.pl/nieruchomosci-rynek-pierwotny/
# https://ogloszenia.trojmiasto.pl/nieruchomosci-mam-do-wynajecia/
# https://ogloszenia.trojmiasto.pl/nieruchomosci-mam-do-wynajecia/a2i,1.html
# https://ogloszenia.trojmiasto.pl/praca/
# https://ogloszenia.trojmiasto.pl/praca-zatrudnie/
# https://ogloszenia.trojmiasto.pl/praca-szukam-pracy/
# https://ogloszenia.trojmiasto.pl/praca-zatrudnie/slwp,59.html
# https://ogloszenia.trojmiasto.pl/motoryzacja/
# https://ogloszenia.trojmiasto.pl/uslugi/mi,1.html
# https://ogloszenia.trojmiasto.pl/
# https://ogloszenia.trojmiasto.pl/dodaj_ogloszenie.html
# https://forum.trojmiasto.pl/
# ...

# %%
from google.colab import files
files.download('wb.xlsx')
